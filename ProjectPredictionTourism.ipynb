# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_excel('tourism_dataset.xlsx')
pd.DataFrame(df)
# Out:
#                          NationalPark       Thai(Adult)       Thai(Child)  \
# 0                            เขาใหญ่                 40                20
# 1                              ทับลาน                20                10
# 2                             ปางสีดา                40                20
# 3                             ตาพระยา                20                10
# 4                       น้ำตกสามหลั่น                20                10
# ..                                ...               ...               ...
# 151                  น้ำตกแม่สุรินทร์                40                20
# 152                           สาละวิน                20                10
# 153               แม่เงา (เตรียมการฯ)  ไม่เสียค่าบริการ  ไม่เสียค่าบริการ
# 154           แม่สะเรียง (เตรียมการฯ)  ไม่เสียค่าบริการ  ไม่เสียค่าบริการ
# 155  เจ็ดคด-โป่งก้อนเส้า (เตรียมการฯ)  ไม่เสียค่าบริการ  ไม่เสียค่าบริการ
#
#        Foreign(Adult)    Foreign(Child)    Year  TempOct  TempNov  TempDec  \
# ...

# %%
import pandas as pd
excel_file = "tourism_dataset.xlsx"
df = pd.read_excel(excel_file)
csv_file = "tourism_dataset.csv"
df.to_csv(csv_file, index=False)

# %%
df = pd.read_csv('tourism_dataset.csv')
pd.DataFrame(df)
# Out:
#                          NationalPark       Thai(Adult)       Thai(Child)  \
# 0                            เขาใหญ่                 40                20
# 1                              ทับลาน                20                10
# 2                             ปางสีดา                40                20
# 3                             ตาพระยา                20                10
# 4                       น้ำตกสามหลั่น                20                10
# ..                                ...               ...               ...
# 151                  น้ำตกแม่สุรินทร์                40                20
# 152                           สาละวิน                20                10
# 153               แม่เงา (เตรียมการฯ)  ไม่เสียค่าบริการ  ไม่เสียค่าบริการ
# 154           แม่สะเรียง (เตรียมการฯ)  ไม่เสียค่าบริการ  ไม่เสียค่าบริการ
# 155  เจ็ดคด-โป่งก้อนเส้า (เตรียมการฯ)  ไม่เสียค่าบริการ  ไม่เสียค่าบริการ
#
#        Foreign(Adult)    Foreign(Child)    Year  TempOct  TempNov  TempDec  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 156 entries, 0 to 155
# Data columns (total 31 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   NationalPark    156 non-null    object
#  1   Thai(Adult)     156 non-null    object
#  2   Thai(Child)     156 non-null    object
#  3   Foreign(Adult)  156 non-null    object
#  4   Foreign(Child)  156 non-null    object
#  5   Year            155 non-null    float64
#  6   TempOct         155 non-null    float64
#  7   TempNov         155 non-null    float64
#  8   TempDec         155 non-null    float64
#  9   TempJan         155 non-null    float64
#  10  TempFeb         155 non-null    float64
#  11  TempMar         155 non-null    float64
#  12  TempApr         155 non-null    float64
#  13  TempMay         155 non-null    float64
#  14  TempJune        155 non-null    float64
#  15  TempJuly        155 non-null    float64
#  16  TempAug         155 non-null    float64
# ...

# %%
import pandas as pd
import matplotlib.pyplot as plt

df['Temperature'] = df[['TempOct', 'TempNov', 'TempDec', 'TempJan', 'TempFeb', 'TempMar', 'TempApr', 'TempMay', 'TempJune', 'TempJuly', 'TempAug', 'TempSep']].mean(axis=1)

temperature_groups = df.groupby('Temperature').size()

plt.figure(figsize=(10, 6))
temperature_groups.plot(kind='bar', color='skyblue')
plt.title('Number of Records for Each Average Temperature')
plt.xlabel('Average Temperature')
plt.ylabel('Number of Records')
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt

df = pd.read_csv('tourism_dataset.csv')

df['Tourism'] = df[['TourismOct', 'TourismNov', 'TourismDec', 'TourismJan', 'TourismFeb', 'TourismMar', 'TourismApr', 'TourismMay', 'TourismJune', 'TourismJuly', 'TourismAug', 'TourismSep']].mean(axis=1)

tourism_counts = df['Tourism'].value_counts().reset_index()

plt.figure(figsize=(10, 6))
plt.bar(tourism_counts['index'], tourism_counts['Tourism'], color='skyblue')
plt.title('Number of Records for Each Average Tourism')
plt.xlabel('Average Tourism')
plt.ylabel('Number of Records')
plt.show()

# %%
import pandas as pd

df = pd.read_csv('tourism_dataset.csv')
df = df.drop('Year', axis=1)

df.to_csv('tourism_dataset.csv', index=False)

# %%
df = pd.read_csv('tourism_dataset.csv')
pd.DataFrame(df)
# Out:
#                          NationalPark       Thai(Adult)       Thai(Child)  \
# 0                            เขาใหญ่                 40                20
# 1                              ทับลาน                20                10
# 2                             ปางสีดา                40                20
# 3                             ตาพระยา                20                10
# 4                       น้ำตกสามหลั่น                20                10
# ..                                ...               ...               ...
# 151                  น้ำตกแม่สุรินทร์                40                20
# 152                           สาละวิน                20                10
# 153               แม่เงา (เตรียมการฯ)  ไม่เสียค่าบริการ  ไม่เสียค่าบริการ
# 154           แม่สะเรียง (เตรียมการฯ)  ไม่เสียค่าบริการ  ไม่เสียค่าบริการ
# 155  เจ็ดคด-โป่งก้อนเส้า (เตรียมการฯ)  ไม่เสียค่าบริการ  ไม่เสียค่าบริการ
#
#        Foreign(Adult)    Foreign(Child)  TempOct  TempNov  TempDec  TempJan  \
# ...

# %%
df.describe()
# Out:
#           TempOct     TempNov     TempDec     TempJan     TempFeb     TempMar  \
# count  155.000000  155.000000  155.000000  155.000000  155.000000  155.000000
# mean    27.329677   27.405806   25.552258   26.587097   27.061935   28.985806
# std      0.636261    0.660503    1.067789    1.362804    1.174141    0.735945
# min     25.500000   25.500000   22.300000   23.200000   23.300000   27.300000
# 25%     27.100000   27.100000   24.900000   25.700000   26.500000   28.600000
# 50%     27.200000   27.500000   25.900000   27.300000   27.600000   29.100000
# 75%     27.800000   27.800000   26.200000   27.500000   27.800000   29.500000
# max     28.300000   28.500000   27.000000   28.500000   28.300000   30.000000
#
#           TempApr    TempMay    TempJune    TempJuly  ...     TourismJan  \
# count  155.000000  155.00000  155.000000  155.000000  ...     155.000000
# mean    28.861290   28.74000   29.262581   28.547742  ...    9508.180645
# ...

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# สร้างแผนภูมิ Boxplot โดยใช้ Seaborn
plt.figure(figsize=(12, 8))
sns.boxplot(data=df, orient="h")  # orient="h" หมายถึงแสดงแนวนอน
plt.title('Boxplot for All Columns')
plt.show()

# %%
df.isnull().sum()
# Out:
# NationalPark      0
# Thai(Adult)       0
# Thai(Child)       0
# Foreign(Adult)    0
# Foreign(Child)    0
# TempOct           1
# TempNov           1
# TempDec           1
# TempJan           1
# TempFeb           1
# TempMar           1
# TempApr           1
# TempMay           1
# TempJune          1
# TempJuly          1
# TempAug           1
# TempSep           1
# TourismOct        1
# TourismNov        1
# TourismDec        1
# TourismJan        1
# TourismFeb        1
# TourismMar        1
# TourismApr        1
# TourismMay        1
# TourismJune       1
# TourismJuly       1
# TourismAug        1
# TourismSep        1
# TourismTotal      1
# dtype: int64

# %%
#ค่าเฉลี่ยของ Dataset
import pandas as pd

df = pd.read_csv('tourism_dataset.csv')
means = df.mean()

print(means)
# Out:
# TempOct            27.329677
# TempNov            27.405806
# TempDec            25.552258
# TempJan            26.587097
# TempFeb            27.061935
# TempMar            28.985806
# TempApr            28.861290
# TempMay            28.740000
# TempJune           29.262581
# TempJuly           28.547742
# TempAug            28.106452
# TempSep            27.563871
# TourismOct       4298.045161
# TourismNov       5567.774194
# TourismDec      12141.077419
# TourismJan       9508.180645
# TourismFeb       5029.277419
# TourismMar       4984.490323
# TourismApr       9669.735484
# TourismMay       5255.045161
# TourismJune      3863.941935
# TourismJuly      6189.122581
# TourismAug       4428.322581
# TourismSep       3167.354839
# TourismTotal    74102.367742
# dtype: float64
# ...

# %%
import pandas as pd

df = pd.read_csv('tourism_dataset.csv')
new_values = list(range(1, 157))
df['NationalPark'] = new_values
df.to_csv('tourism_dataset.csv', index=False)

df = pd.read_csv('tourism_dataset.csv')
pd.DataFrame(df)
# Out:
#      NationalPark       Thai(Adult)       Thai(Child)    Foreign(Adult)  \
# 0               1                40                20               400
# 1               2                20                10               100
# 2               3                40                20               200
# 3               4                20                10               100
# 4               5                20                10               100
# ..            ...               ...               ...               ...
# 151           152                40                20               200
# 152           153                20                10               100
# 153           154  ไม่เสียค่าบริการ  ไม่เสียค่าบริการ  ไม่เสียค่าบริการ
# 154           155  ไม่เสียค่าบริการ  ไม่เสียค่าบริการ  ไม่เสียค่าบริการ
# 155           156  ไม่เสียค่าบริการ  ไม่เสียค่าบริการ  ไม่เสียค่าบริการ
#
#        Foreign(Child)  TempOct  TempNov  TempDec  TempJan  TempFeb  ...  \
# ...

# %%
#แทนที่ค่า Missing Value
df = pd.read_csv('tourism_dataset.csv')
means = df.mean()
df_filled = df.fillna(means)
df_filled.to_csv('tourism_dataset.csv', index=False)
df = pd.read_csv('tourism_dataset.csv')
pd.DataFrame(df)
# Out:
# <ipython-input-36-1ab40fd1da44>:3: FutureWarning: The default value of numeric_only in DataFrame.mean is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   means = df.mean()
#      NationalPark       Thai(Adult)       Thai(Child)    Foreign(Adult)  \
# 0               1                40                20               400
# 1               2                20                10               100
# 2               3                40                20               200
# 3               4                20                10               100
# 4               5                20                10               100
# ..            ...               ...               ...               ...
# 151           152                40                20               200
# ...

# %%
#ตรวจสอบค่า Outlier ใน Dataset
df = pd.read_csv('tourism_dataset.csv')

Q1 = df.quantile(0.25)
Q3 = df.quantile(0.75)
IQR = Q3 - Q1

lower_bound = Q1 - 1.5 * IQR
upper_bound = Q3 + 1.5 * IQR

outliers = ((df < lower_bound) | (df > upper_bound))

print(outliers.sum())
# Out:
# Foreign(Adult)     0
# Foreign(Child)     0
# NationalPark       0
# TempApr           42
# TempAug            0
# TempDec            5
# TempFeb            5
# TempJan            0
# TempJuly           0
# TempJune           0
# TempMar            0
# TempMay           37
# TempNov            5
# TempOct            5
# TempSep            0
# Thai(Adult)        0
# Thai(Child)        0
# TourismApr        19
# TourismAug        13
# TourismDec        19
# TourismFeb        19
# TourismJan        14
# TourismJuly       17
# TourismJune       15
# TourismMar        21
# TourismMay        19
# TourismNov        16
# TourismOct        15
# TourismSep        16
# TourismTotal      14
# dtype: int64
# <ipython-input-37-5a61394ed7e3>:4: FutureWarning: The default value of numeric_only in DataFrame.quantile is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   Q1 = df.quantile(0.25)
# ...

# %%
#กำจัดค่า Outlier ด้วยค่าเฉลี่ยของแต่ละคอลลัมน์และแสดงผลค่าที่กำจัดแล้ว
df = pd.read_csv('tourism_dataset.csv')

columns_to_remove_outliers = [
    'TempApr', 'TempMay', 'TempDec', 'TempFeb',
    'TempNov', 'TempOct', 'TourismApr', 'TourismAug',
    'TourismDec', 'TourismFeb', 'TourismJan', 'TourismJuly',
    'TourismJune', 'TourismMar', 'TourismMay', 'TourismNov',
    'TourismOct', 'TourismSep', 'TourismTotal'
]

Q1 = df[columns_to_remove_outliers].quantile(0.25)
Q3 = df[columns_to_remove_outliers].quantile(0.75)
IQR = Q3 - Q1

lower_bound = Q1 - 1.5 * IQR
upper_bound = Q3 + 1.5 * IQR

outliers = ((df[columns_to_remove_outliers] < lower_bound) | (df[columns_to_remove_outliers] > upper_bound))

column_means = df[columns_to_remove_outliers].mean()

for column in columns_to_remove_outliers:
    df[column] = df[column].apply(lambda x: column_means[column] if x in outliers[column] else x)

df.to_csv('tourism_dataset.csv', index=False)
df = pd.read_csv('tourism_dataset.csv')
pd.DataFrame(df)
# Out:
#      NationalPark       Thai(Adult)       Thai(Child)    Foreign(Adult)  \
# 0               1                40                20               400
# 1               2                20                10               100
# 2               3                40                20               200
# 3               4                20                10               100
# 4               5                20                10               100
# ..            ...               ...               ...               ...
# 151           152                40                20               200
# 152           153                20                10               100
# 153           154  ไม่เสียค่าบริการ  ไม่เสียค่าบริการ  ไม่เสียค่าบริการ
# 154           155  ไม่เสียค่าบริการ  ไม่เสียค่าบริการ  ไม่เสียค่าบริการ
# 155           156  ไม่เสียค่าบริการ  ไม่เสียค่าบริการ  ไม่เสียค่าบริการ
#
#        Foreign(Child)    TempOct    TempNov    TempDec    TempJan    TempFeb  \
# ...

# %%
#หาค่า Duplicate ใน Dataset
df = pd.read_csv('tourism_dataset.csv')

duplicates = df[df.duplicated()]

print(duplicates)
# Out:
# Empty DataFrame
# Columns: [NationalPark, Thai(Adult), Thai(Child), Foreign(Adult), Foreign(Child), TempOct, TempNov, TempDec, TempJan, TempFeb, TempMar, TempApr, TempMay, TempJune, TempJuly, TempAug, TempSep, TourismOct, TourismNov, TourismDec, TourismJan, TourismFeb, TourismMar, TourismApr, TourismMay, TourismJune, TourismJuly, TourismAug, TourismSep, TourismTotal]
# Index: []
#
# [0 rows x 30 columns]

# %%
df = pd.read_csv('tourism_dataset.csv')
pd.DataFrame(df)
# Out:
#      NationalPark       Thai(Adult)       Thai(Child)    Foreign(Adult)  \
# 0               1                40                20               400
# 1               2                20                10               100
# 2               3                40                20               200
# 3               4                20                10               100
# 4               5                20                10               100
# ..            ...               ...               ...               ...
# 151           152                40                20               200
# 152           153                20                10               100
# 153           154  ไม่เสียค่าบริการ  ไม่เสียค่าบริการ  ไม่เสียค่าบริการ
# 154           155  ไม่เสียค่าบริการ  ไม่เสียค่าบริการ  ไม่เสียค่าบริการ
# 155           156  ไม่เสียค่าบริการ  ไม่เสียค่าบริการ  ไม่เสียค่าบริการ
#
#        Foreign(Child)    TempOct    TempNov    TempDec    TempJan    TempFeb  \
# ...

# %%
import warnings
warnings.filterwarnings("ignore")
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.svm import SVR
from sklearn.neural_network import MLPRegressor
from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score
from sklearn.preprocessing import MinMaxScaler
import pickle
from sklearn.neighbors import KNeighborsRegressor
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# %%
X = df[['TempOct', 'TempNov', 'TempDec', 'TempJan', 'TempFeb', 'TempMar', 'TempApr', 'TempMay', 'TempJune', 'TempJune', 'TempJuly', 'TempAug', 'TempSep']]
X
# Out:
#        TempOct    TempNov    TempDec    TempJan    TempFeb    TempMar  \
# 0    27.100000  27.405806  23.700000  25.700000  26.200000  29.500000
# 1    28.300000  28.500000  26.400000  27.600000  28.200000  29.900000
# 2    28.300000  28.500000  26.400000  27.600000  28.200000  29.900000
# 3    27.800000  27.900000  25.700000  27.300000  27.800000  29.600000
# 4    28.100000  27.405806  25.900000  27.300000  27.700000  29.400000
# ..         ...        ...        ...        ...        ...        ...
# 151  28.300000  28.500000  26.400000  27.600000  28.200000  29.900000
# 152  28.300000  28.500000  26.400000  27.600000  28.200000  29.900000
# 153  27.800000  27.900000  25.700000  27.300000  27.800000  29.600000
# 154  28.100000  27.405806  25.900000  27.300000  27.700000  29.400000
# 155  27.329677  27.405806  25.552258  26.587097  27.061935  28.985806
#
#       TempApr  TempMay   TempJune   TempJune   TempJuly    TempAug    TempSep
# ...

# %%
Y = df[['TourismOct', 'TourismNov', 'TourismDec', 'TourismJan', 'TourismFeb', 'TourismMar', 'TourismApr', 'TourismMay', 'TourismJune', 'TourismJuly', 'TourismAug', 'TourismSep']]
Y
# Out:
#         TourismOct     TourismNov     TourismDec     TourismJan    TourismFeb  \
# 0    157662.000000  156093.000000  250501.000000  158936.000000  79772.000000
# 1      4298.045161   14391.000000   33159.000000   21317.000000  14329.000000
# 2      9256.000000    6273.000000    4599.000000    4472.000000   1356.000000
# 3       186.000000     263.000000     629.000000     332.000000    265.000000
# 4      4793.000000    5852.000000    6787.000000    4420.000000   1384.000000
# ..             ...            ...            ...            ...           ...
# 151     200.000000    3369.000000    1202.000000     382.000000    185.000000
# 152    4298.045161    5567.774194     292.000000     289.000000   5029.277419
# 153    4298.045161     340.000000    1420.000000     535.000000    374.000000
# 154    4298.045161    5567.774194   12141.077419    9508.180645   5029.277419
# 155    4298.045161    5567.774194   12141.077419    9508.180645   5029.277419
#
# ...

# %%
scaler = MinMaxScaler()

# %%
X_norm = scaler.fit_transform(X)
X_norm
# Out:
# array([[0.57142857, 0.63526882, 0.31111111, ..., 0.65384615, 0.46666667,
#         0.33333333],
#        [1.        , 1.        , 0.91111111, ..., 0.76923077, 0.53333333,
#         0.88888889],
#        [1.        , 1.        , 0.91111111, ..., 0.76923077, 0.53333333,
#         0.88888889],
#        ...,
#        [0.82142857, 0.8       , 0.75555556, ..., 0.69230769, 0.46666667,
#         0.61111111],
#        [0.92857143, 0.63526882, 0.8       , ..., 0.73076923, 0.66666667,
#         0.83333333],
#        [0.65345622, 0.63526882, 0.72272401, ..., 0.55682382, 0.47096774,
#         0.53548387]])

# %%
# แบ่งข้อมูลเป็นชุดการฝึกและชุดทดสอบ
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.2, random_state=42)

# %%
print("Train shape: ", X_train.shape)
print("Test shape: ", X_test.shape)
# Out:
# Train shape:  (124, 13)
# Test shape:  (32, 13)

# %%
# สร้างโมเดล Linear Regression
lr = LinearRegression()

# ฝึกโมเดลโดยใช้ชุดการฝึก
lr.fit(X_train, Y_train)
# Out:
# LinearRegression()

# %%
# สร้างโมเดล KNN
knn = KNeighborsRegressor(n_neighbors=5)  # กำหนดจำนวนเพื่อบรรทัด k (เช่น n_neighbors=5)

# ทำการเทรนโมเดล KNN ด้วยข้อมูลการฝึกอบรม
knn.fit(X_train, Y_train)

# ทำการทำนายด้วยข้อมูลทดสอบ
y_knn_pred = knn.predict(X_test)

# %%
def calculate_metrics(X, Y, model):
    pred = model.predict(X)
    mse = mean_squared_error(Y, pred)
    rmse = mse ** 0.5
    mae = mean_absolute_error(Y, pred)
    r2 = r2_score(Y, pred)

    return rmse, mae, r2

# %%
lr_rmse, lr_mae, lr_r2 = calculate_metrics(X_test, Y_test, lr)
print(f"RMSE: {lr_rmse}")
print(f"MAE: {lr_mae}")
print(f"R^2: {lr_r2}")
# Out:
# RMSE: 8227.778588881263
# MAE: 5836.36593081287
# R^2: -1.014171290407619

# %%
knn_rmse, knn_mae, knn_r2 = calculate_metrics(X_test, Y_test, knn)
print(f"RMSE: {knn_rmse}")
print(f"MAE: {knn_mae}")
print(f"R^2: {knn_r2}")
# Out:
# RMSE: 9508.95963497822
# MAE: 6293.371676747313
# R^2: -1.9232675994606552

# %%
import pandas as pd

# สร้างข้อมูลในรูปแบบ Dictionary
data = {
    'Model': ['Linear Regression', 'K-Nearest Neighbors (KNN)'],
    'RMSE': [8227.778588881263, 9508.95963497822],
    'MAE': [5836.36593081287, 6293.371676747313],
    'R^2': [-1.014171290407619, -1.9232675994606552]
}

# สร้าง DataFrame
df = pd.DataFrame(data)

# แสดง DataFrame
print(df)
# Out:
#                        Model         RMSE          MAE       R^2
# 0          Linear Regression  8227.778589  5836.365931 -1.014171
# 1  K-Nearest Neighbors (KNN)  9508.959635  6293.371677 -1.923268

# %%
# สร้างกราฟแท่ง
fig, ax = plt.subplots(figsize=(10, 6))
bar_width = 0.2
index = range(len(df))

# สร้างแท่งกราฟสำหรับ RMSE
plt.bar(index, df['RMSE'], bar_width, label='RMSE', align='center', alpha=0.7)

# สร้างแท่งกราฟสำหรับ MAE
plt.bar([i + bar_width for i in index], df['MAE'], bar_width, label='MAE', align='center', alpha=0.7)

# สร้างแท่งกราฟสำหรับ R^2
plt.bar([i + 2 * bar_width for i in index], df['R^2'], bar_width, label='R^2', align='center', alpha=0.7)

# กำหนดค่าในแกน X
plt.xticks([i + bar_width for i in index], df['Model'])

# กำหนดค่าในแกน Y
plt.ylabel('Value')
plt.title('RMSE, MAE,  R^2 of Model ')
plt.legend()
plt.tight_layout()

# แสดงกราฟ
plt.show()

# %%
y_lr_pred = lr.predict(X_test[:30])
y_lr_pred
# Out:
# array([[ 5719.11545658,  5149.21718818,  8128.92372807,  6152.33122652,
#          4166.29956622,  5196.75092162, 12777.95266968,  7562.30740909,
#          4611.08354358,  6240.86185154,  4855.97249748,  3288.40744808],
#        [ 2696.79474352,  1852.18226074,  5444.61171081,  3581.40398581,
#          1395.96987938,  3774.78814431, 12965.63121144,  6937.08064899,
#          3032.42518835,  6394.00149482,  5619.42065624,  2787.34329672],
#        [ 1195.75759902,  4040.0341494 , 13096.8892424 ,  8977.23348423,
#          6821.02762789,  8986.58457729, 13430.08503998,  4634.99546392,
#          2333.94012247,  5375.29619968,  4020.34444465,  1888.30539978],
#        [ -267.51978503,  -871.70150371,  3981.80719537,  1613.3025308 ,
#          1777.6422629 ,  3474.66689509,  4663.04298982,  1478.86510192,
#         -1145.36307901, -1946.46350278,  -145.2627099 ,  -858.74085555],
#        [ 5839.27382147,  8368.96507784, 16889.6397733 , 12090.6316203 ,
# ...

# %%
y_knn_pred = knn.predict(X_test[:30])
y_knn_pred
# Out:
# array([[ 2111.00903226,  1634.4       ,  3900.4       ,  4208.2       ,
#          1828.2       ,  2685.6       ,  8595.6       ,  3370.20903226,
#          2503.3883871 ,  2873.22451613,  2050.66451613,  1239.6       ],
#        [15739.20903226, 14282.75483871, 23162.8       , 15475.4       ,
#          8766.        , 13683.49806452, 32268.2       , 22178.6       ,
#         12735.        , 18251.42451613, 15099.72903226,  9286.54193548],
#        [ 3424.4       ,  6289.8       , 13355.4       , 11081.        ,
#          8548.2       , 13017.69806452, 20506.6       ,  9579.        ,
#          4723.7883871 ,  6996.84903226,  6112.79354839,  4133.94193548],
#        [ 3799.41806452,  3600.75483871, 17544.81548387, 10563.03612903,
#          2382.6       ,  1858.        ,  2809.4       ,  2315.        ,
#          1720.2       ,  4912.04903226,  3391.72903226,  2188.87096774],
#        [ 2146.60903226,  3617.15483871,  4006.8       ,  3748.        ,
# ...

# %%
Y_test_1d = Y_test[:30].values.ravel()  # แปลง Y_test ให้เป็น 1D
y_lr_pred_1d = y_lr_pred[:30].flatten()  # แปลง y_lr_pred ให้เป็น 1D

sns.lineplot(x=np.arange(len(Y_test_1d)), y=Y_test_1d, label='Actual')
sns.lineplot(x=np.arange(len(y_lr_pred_1d)), y=y_lr_pred_1d, label='Predicted Linear Regression')

plt.xlabel("Data Point")
plt.ylabel("y_test Value")
plt.legend()
plt.show()

# %%
Y_test_1d = Y_test[:30].values.ravel()  # แปลง Y_test ให้เป็น 1D
y_knn_pred_1d = y_knn_pred[:30].flatten()  # แปลง y_knn_pred ให้เป็น 1D

sns.lineplot(x=np.arange(len(Y_test_1d)), y=Y_test_1d, label='Actual')
sns.lineplot(x=np.arange(len(y_knn_pred_1d)), y=y_knn_pred_1d, label='Predicted K-Nearest Neighbors Algorithm')

plt.xlabel("Data Point")
plt.ylabel("y_test Value")
plt.legend()
plt.show()

# %%
plt.figure(figsize=(12, 6))
sns.lineplot(x=np.arange(len(Y_test_1d)), y=Y_test_1d, label='Actual')
sns.lineplot(x=np.arange(len(y_lr_pred_1d)), y=y_lr_pred_1d, label='Predicted Linear Regression')
sns.lineplot(x=np.arange(len(y_knn_pred_1d)), y=y_knn_pred_1d, label='Predicted K-Nearest Neighbors Algorithm')
plt.xlabel("Data Point")
plt.ylabel("y_test Value")
plt.figure(figsize=(12, 4))
plt.show()
